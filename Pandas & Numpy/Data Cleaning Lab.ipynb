# %% [markdown]
# 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data

# %%
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# 3. Create a mysql engine to set the connection to the server.

# %%
## General syntax: 'mysql+pymysql://usrnme:passwd@hstnme:/dbname'

engine = create_engine("mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/stats")

# %%
engine
# Out:
# Engine(mysql+pymysql://guest:***@relational.fit.cvut.cz:3306/stats)

# %% [markdown]
# 4. Import the users table

# %%
df = pd.read_sql('SELECT * FROM users', engine)
df
# Out:
#           Id  Reputation        CreationDate     DisplayName  \
# 0         -1           1 2010-07-19 06:55:26       Community
# 1          2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27          Emmett
# 4          5        6792 2010-07-19 19:03:57           Shane
# ...      ...         ...                 ...             ...
# 40320  55743           1 2014-09-13 21:03:50       AussieMeg
# 40321  55744           6 2014-09-13 21:39:30       Mia Maria
# 40322  55745         101 2014-09-13 23:45:27    tronbabylove
# 40323  55746         106 2014-09-14 00:29:41             GPP
# 40324  55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %%
df.keys()
# Out:
# Index(['Id', 'Reputation', 'CreationDate', 'DisplayName', 'LastAccessDate',
#        'WebsiteUrl', 'Location', 'AboutMe', 'Views', 'UpVotes', 'DownVotes',
#        'AccountId', 'Age', 'ProfileImageUrl'],
#       dtype='object')

# %% [markdown]
# 5. Rename Id column to userId

# %%
users = df.rename(columns={'Id': 'userId'})
users.head()
# Out:
#    userId  Reputation        CreationDate   DisplayName      LastAccessDate  \
# 0      -1           1 2010-07-19 06:55:26     Community 2010-07-19 06:55:26
# 1       2         101 2010-07-19 14:01:36  Geoff Dalgas 2013-11-12 22:07:23
# 2       3         101 2010-07-19 15:34:50  Jarrod Dixon 2014-08-08 06:42:58
# 3       4         101 2010-07-19 19:03:27        Emmett 2014-01-02 09:31:02
# 4       5        6792 2010-07-19 19:03:57         Shane 2014-08-13 00:23:47
#
#                        WebsiteUrl            Location  \
# 0  http://meta.stackexchange.com/  on the server farm
# 1        http://stackoverflow.com       Corvallis, OR
# 2        http://stackoverflow.com        New York, NY
# 3    http://minesweeperonline.com   San Francisco, CA
# 4         http://www.statalgo.com        New York, NY
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0     5007
# ...

# %% [markdown]
# 6. Import the posts table.

# %%
df2 = pd.read_sql('SELECT * FROM posts', engine)
df2
# Out:
#            Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# ...       ...         ...               ...                 ...    ...
# 91971  115374           2               NaN 2014-09-13 23:45:39      2
# 91972  115375           1               NaN 2014-09-13 23:46:05      0
# 91973  115376           1               NaN 2014-09-14 01:27:54      1
# 91974  115377           2               NaN 2014-09-14 02:03:28      0
# 91975  115378           2               NaN 2014-09-14 02:09:23      0
#
#        ViewCount                                               Body  \
# ...

# %% [markdown]
# 7. Rename Id column to postId and OwnerUserId to userId

# %%
posts = df2.rename(columns={'Id': 'postId', 'OwnerUserId': 'userId' })
posts.head()
# Out:
#    postId  PostTypeId  AcceptedAnswerId         CreaionDate  Score  ViewCount  \
# 0       1           1              15.0 2010-07-19 19:12:12     23     1278.0
# 1       2           1              59.0 2010-07-19 19:12:57     22     8198.0
# 2       3           1               5.0 2010-07-19 19:13:28     54     3613.0
# 3       4           1             135.0 2010-07-19 19:13:31     13     5224.0
# 4       5           2               NaN 2010-07-19 19:14:43     81        NaN
#
#                                                 Body  userId  \
# 0  <p>How should I elicit prior distributions fro...     8.0
# 1  <p>In many different statistical methods there...    24.0
# 2  <p>What are some valuable Statistical Analysis...    18.0
# 3  <p>I have two groups of data.  Each with a dif...    23.0
# 4  <p>The R-project</p>\n\n<p><a href="http://www...    23.0
#
#       LasActivityDate                                              Title  ...  \
# ...

# %%
posts.keys()
# Out:
# Index(['postId', 'PostTypeId', 'AcceptedAnswerId', 'CreaionDate', 'Score',
#        'ViewCount', 'Body', 'userId', 'LasActivityDate', 'Title', 'Tags',
#        'AnswerCount', 'CommentCount', 'FavoriteCount', 'LastEditorUserId',
#        'LastEditDate', 'CommunityOwnedDate', 'ParentId', 'ClosedDate',
#        'OwnerDisplayName', 'LastEditorDisplayName'],
#       dtype='object')

# %% [markdown]
# 8. Define new dataframes for users and posts with the following selected columns:
#
# **users columns**: userId, Reputation,Views,UpVotes,DownVotes <br/>
# **posts columns**: postId, Score,userId,ViewCount,CommentCount

# %%
select_cols_users = ['userId', 'Reputation', 'Views', 'UpVotes', 'DownVotes']
select_cols_posts = ['postId', 'Score', 'userId', 'ViewCount', 'CommentCount']

# %%
df_users = users[select_cols_users]
df_posts = posts[select_cols_posts]

# %%
df_users.head()
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes
# 0      -1           1      0     5007       1920
# 1       2         101     25        3          0
# 2       3         101     22       19          0
# 3       4         101     11        0          0
# 4       5        6792   1145      662          5

# %%
df_posts.head()
# Out:
#    postId  Score  userId  ViewCount  CommentCount
# 0       1     23     8.0     1278.0             1
# 1       2     22    24.0     8198.0             1
# 2       3     54    18.0     3613.0             4
# 3       4     13    23.0     5224.0             2
# 4       5     81    23.0        NaN             3

# %% [markdown]
# 8. Merge both dataframes, users and posts.

# %%
new_df = df_users.merge(df_posts, on='userId')
new_df.head()
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes  postId  Score  ViewCount  \
# 0      -1           1      0     5007       1920    2175      0        NaN
# 1      -1           1      0     5007       1920    8576      0        NaN
# 2      -1           1      0     5007       1920    8578      0        NaN
# 3      -1           1      0     5007       1920    8981      0        NaN
# 4      -1           1      0     5007       1920    8982      0        NaN
#
#    CommentCount
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# 9. How many missing values do you have in your merged dataframe? On which columns?

# %%
null_cols = new_df.isnull().sum()
null_cols
# Out:
# userId              0
# Reputation          0
# Views               0
# UpVotes             0
# DownVotes           0
# postId              0
# Score               0
# ViewCount       48396
# CommentCount        0
# dtype: int64

# %%
len(new_df)
# Out:
# 90584

# %% [markdown]
# 10. You will need to make something with missing values. Will you clean or filling them? Explain.
#
# **Remember** to check the results of your code before passing to the next step

# %%
## Since more than half out of the total data for the ViewCount has null values (48,396 out of 90,584)
## we've decided to drop the column

new_df = new_df.drop(['ViewCount'], axis=1)

# %%
new_df.head()
# Out:
#    userId  Reputation  Views  UpVotes  DownVotes  postId  Score  CommentCount
# 0      -1           1      0     5007       1920    2175      0             0
# 1      -1           1      0     5007       1920    8576      0             0
# 2      -1           1      0     5007       1920    8578      0             0
# 3      -1           1      0     5007       1920    8981      0             0
# 4      -1           1      0     5007       1920    8982      0             0

# %% [markdown]
# 11. Adjust the data types in order to avoid future issues. Which ones should be changed?

# %%
new_df.dtypes
# Out:
# userId          int64
# Reputation      int64
# Views           int64
# UpVotes         int64
# DownVotes       int64
# postId          int64
# Score           int64
# CommentCount    int64
# dtype: object

# %% [markdown]
# Bonus: Identify extreme values in your merged dataframe as you have learned in class, create a dataframe called outliers with the same columns as our data set and calculate the bounds. The values of the outliers dataframe will be the values of the merged_df that fall outside that bounds. You will need to save your outliers dataframe to a csv file on your-code folder.

# %%
## A common method for identifying outliers is one that leverages the interquartile range (IQR). 
## Once the IQR is calculated, it is multiplied by a constant (typically 1.5) and lower and upper bounds are established at:

# 25th Percentile - (IQR x 1.5)
# 75th Percentile + (IQR x 1.5)

# Any values outside this range are potential outliers and should be investigated.

# %%
stats = new_df.describe().transpose()
stats
# Out:
#                 count          mean           std   min       25%      50%  \
# userId        90584.0  16546.764727  15273.367108  -1.0   3437.00  11032.0
# Reputation    90584.0   6282.395412  15102.268670   1.0     60.00    396.0
# Views         90584.0   1034.245176   2880.074012   0.0      5.00     45.0
# UpVotes       90584.0    734.315718   2050.869327   0.0      1.00     22.0
# DownVotes     90584.0     33.273249    134.936435   0.0      0.00      0.0
# postId        90584.0  56539.080522  33840.307529   1.0  26051.75  57225.5
# Score         90584.0      2.780767      4.948922 -19.0      1.00      2.0
# CommentCount  90584.0      1.894650      2.638704   0.0      0.00      1.0
#
#                    75%       max
# userId        27700.00   55746.0
# Reputation     4460.00   87393.0
# Views           514.25   20932.0
# UpVotes         283.00   11442.0
# DownVotes         8.00    1920.0
# postId        86145.25  115378.0
# Score             3.00     192.0
# ...

# %%
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                 count          mean           std   min       25%      50%  \
# userId        90584.0  16546.764727  15273.367108  -1.0   3437.00  11032.0
# Reputation    90584.0   6282.395412  15102.268670   1.0     60.00    396.0
# Views         90584.0   1034.245176   2880.074012   0.0      5.00     45.0
# UpVotes       90584.0    734.315718   2050.869327   0.0      1.00     22.0
# DownVotes     90584.0     33.273249    134.936435   0.0      0.00      0.0
# postId        90584.0  56539.080522  33840.307529   1.0  26051.75  57225.5
# Score         90584.0      2.780767      4.948922 -19.0      1.00      2.0
# CommentCount  90584.0      1.894650      2.638704   0.0      0.00      1.0
#
#                    75%       max       IQR
# userId        27700.00   55746.0  24263.00
# Reputation     4460.00   87393.0   4400.00
# Views           514.25   20932.0    509.25
# UpVotes         283.00   11442.0    282.00
# DownVotes         8.00    1920.0      8.00
# ...

# %%
outliers = pd.DataFrame(columns=new_df.columns)
outliers
# Out:
# Empty DataFrame
# Columns: [userId, Reputation, Views, UpVotes, DownVotes, postId, Score, CommentCount]
# Index: []

# %%
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 3
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = new_df[(new_df[col] < lower) | 
                   (new_df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = pd.concat([outliers, results])

# %%
outliers
# Out:
#       userId Reputation Views UpVotes DownVotes  postId Score CommentCount  \
# 1733     159      18283  3781    1014        59     167    10            4
# 1734     159      18283  3781    1014        59     169     2            0
# 1735     159      18283  3781    1014        59     171     8            0
# 1736     159      18283  3781    1014        59     174    35            0
# 1737     159      18283  3781    1014        59     177    22            2
# ...      ...        ...   ...     ...       ...     ...   ...          ...
# 89621  54099        719    69      31         4  113461     1           13
# 89800  54300         60    64      14         6  113498     3           14
# 89965  54581        111     2       0         0  113011     2           14
# 90064  54736         96    14       5         0  113314     7           17
# 90130  54862         14     9       3         0  113598     2           17
#
#             Outlier
# 1733     Reputation
# 1734     Reputation
# ...
