# %% [markdown]
# ## Challenge 1: Fork Languages

# %% [markdown]
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# Obtain the full list of forks created from the main lab repo via Github API.
#
# Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %%
import requests

# %%
git_api = 'https://api.github.com/repos/ta-data-mex/lab-api-scavenger-game/forks'

# %%
for i in range(1, 3):
    git_api = 'https://api.github.com/repos/ta-data-mex/lab-api-scavenger-game/forks?page={i}'
    respuesta = requests.get(git_api)
    if i == 1:
        dictA = respuesta.json()
    elif i == 2:
        dictB = respuesta.json()

# %%
dictA.extend(dictB)

# %%
dictA
# Out:
# [{'id': 405137014,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MDUxMzcwMTQ=',
#   'name': 'lab-api-scavenger-game',
#   'full_name': 'juanmanuelvillacis/lab-api-scavenger-game',
#   'private': False,
#   'owner': {'login': 'juanmanuelvillacis',
#    'id': 88158593,
#    'node_id': 'MDQ6VXNlcjg4MTU4NTkz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88158593?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/juanmanuelvillacis',
#    'html_url': 'https://github.com/juanmanuelvillacis',
#    'followers_url': 'https://api.github.com/users/juanmanuelvillacis/followers',
#    'following_url': 'https://api.github.com/users/juanmanuelvillacis/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/juanmanuelvillacis/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/juanmanuelvillacis/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/juanmanuelvillacis/subscriptions',
# ...

# %%
len(dictA)
# Out:
# 60

# %%
fork_lang = []

for i in dictA:
    for key, value in i.items():
        if key == 'language':
            fork_lang.append(value)

# %%
list(set(fork_lang))
# Out:
# ['Jupyter Notebook', 'Python', None]

# %% [markdown]
# ## Challenge 2: Count Commits

# %% [markdown]
# Count how many commits were made in the past week.
#
# Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %%
git_api_2 = 'https://api.github.com/repos/miguelhermar/lab-resolving-git-conflicts/commits?since=2022-07-16'

# %%
respuesta_2 = requests.get(git_api_2)

# %%
commits = respuesta_2.json()
commits
# Out:
# [{'sha': '52013ce5f52c1fe79d7ae776e6ef9d2384a9ebf0',
#   'node_id': 'C_kwDOHyyqm9oAKDUyMDEzY2U1ZjUyYzFmZTc5ZDdhZTc3NmU2ZWY5ZDIzODRhOWViZjA',
#   'commit': {'author': {'name': 'Miguel',
#     'email': 'miguelangel.hermar410@gmail.com',
#     'date': '2022-08-09T17:05:04Z'},
#    'committer': {'name': 'Miguel',
#     'email': 'miguelangel.hermar410@gmail.com',
#     'date': '2022-08-09T17:05:04Z'},
#    'message': 'Conflicto resuelto',
#    'tree': {'sha': '1643a88eb0f1727284dd412dd7be4bec887edd86',
#     'url': 'https://api.github.com/repos/miguelhermar/lab-resolving-git-conflicts/git/trees/1643a88eb0f1727284dd412dd7be4bec887edd86'},
#    'url': 'https://api.github.com/repos/miguelhermar/lab-resolving-git-conflicts/git/commits/52013ce5f52c1fe79d7ae776e6ef9d2384a9ebf0',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
for i in commits:
    print(len(i.keys()))
    break
# Out:
# 9

# %%
for i in commits:
    print(i.keys())
    break
# Out:
# dict_keys(['sha', 'node_id', 'commit', 'url', 'html_url', 'comments_url', 'author', 'committer', 'parents'])

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke

# %% [markdown]
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.

# %%
git_api_3 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'

# %%
respuesta_3 = requests.get(git_api_3)

# %%
type(respuesta_3)
# Out:
# requests.models.Response

# %%
cold_joke = respuesta_3.json()

# %%
for i in cold_joke:
    print(i.keys())
    break
# Out:
# dict_keys(['name', 'path', 'sha', 'size', 'url', 'html_url', 'git_url', 'download_url', 'type', '_links'])

# %%
cold_joke
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...

# %%
names = []

for i in cold_joke:
    for key, value in i.items():
        if key == 'name':
            names.append(value)

# %%
clean_names = names[1:]
clean_names
# Out:
# ['15024',
#  '15534',
#  '17020',
#  '30351',
#  '40303',
#  '44639',
#  '45525',
#  '47222',
#  '47830',
#  '49418',
#  '50896',
#  '55417',
#  '55685',
#  '60224',
#  '64880',
#  '66032',
#  '68848',
#  '70751',
#  '70985',
#  '88596',
#  '89046',
#  '89338',
#  '91701',
#  '97881',
#  '98750']

# %%
len(clean_names)
# Out:
# 25

# %%
new_api_key = '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'

# %%
cont_en_dir = []

k = 0
for i in range(len(clean_names)):
    url= f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{clean_names[k]}'
    response = requests.get(url)
    results = response.json()  
    

    cont_en_dir.append(results)
    k += 1

# %%
cont_en_dir
# Out:
# [[{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'size': 3,
#    'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt',
#    'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#    'type': 'file',
#    '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt?ref=master',
#     'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#     'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/15024/.0006.scavengerhunt'}},
# ...

# %%
docs_names = []

for i in cont_en_dir:
    for j in i:
        for key, value in j.items():
            if key == 'name':
                if value.startswith('.'):
                    docs_names.append(value)

# %%
len(docs_names)
# Out:
# 24

# %%
docs_names
# Out:
# ['.0006.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0024.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0001.scavengerhunt']

# %%
try:
    for i in clean_names:
        i2 = url+i
        for e in docs_names:
            d = i2+'/'+ e

            print(d)
except Exception:
    pass
# Out:
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0008.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0012.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0007.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0021.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0022.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0005.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0018.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0016.scavengerhunt
# https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0024.scavengerhunt
# ...

# %%
url= f'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/'

# %%
hidden_words = []

try:
    for i in clean_names:
        i2 = url+i
        for e in docs_names:
            d = i2+'/'+ e
            response8 = requests.get(d)
            if response8.text.strip() != '404: Not Found':
                hidden_words.append(response8.text.strip())
except IndexError:
    docs = ''

# %%
hidden_words
# Out:
# ['of',
#  'spent',
#  '20',
#  'time',
#  'need',
#  'to',
#  'percent',
#  'complaining',
#  'is',
#  'data.',
#  'preparing',
#  'of',
#  'data,',
#  'prepare',
#  'the',
#  'science,',
#  '80',
#  'about',
#  'spent',
#  'data',
#  'percent',
#  'time',
#  'is',
#  'In']

# %%
" ".join(hidden_words)
# Out:
# 'of spent 20 time need to percent complaining is data. preparing of data, prepare the science, 80 about spent data percent time is In'

# %%
[''.join(x) for x in zip(hidden_words[0::2], hidden_words[1::2])]
# Out:
# ['ofspent',
#  '20time',
#  'needto',
#  'percentcomplaining',
#  'isdata.',
#  'preparingof',
#  'data,prepare',
#  'thescience,',
#  '80about',
#  'spentdata',
#  'percenttime',
#  'isIn']

# %%
new_list = [] 

for i in clean_names:
    i2 = url+i
    for e in docs_names:
        d = i2+'/'+ e
        response_prueba = requests.get(d)
        if response_prueba.text.strip() != '404: Not Found':
            new_list.append(d)

# %%
new_list
# Out:
# ['https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15534/.0008.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15534/.0012.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/17020/.0007.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/30351/.0021.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/40303/.0022.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/44639/.0005.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/45525/.0018.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/47222/.0016.scavengerhunt',
# ...

# %%
new_list_2 = sorted(new_list, key=lambda x: x[-19:])
new_list_2
# Out:
# ['https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/98750/.0001.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/88596/.0002.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/60224/.0003.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/68848/.0004.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/44639/.0005.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15024/.0006.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/17020/.0007.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/15534/.0008.scavengerhunt',
#  'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/97881/.0009.scavengerhunt',
# ...

# %%
hidden_words_prueba = [] 
for e in new_list_2:
    response_aver = requests.get(e, api_key)
    hidden_words_prueba.append(response_aver.text.strip())

# %%
hidden_words_prueba
# Out:
# ['In',
#  'data',
#  'science,',
#  '80',
#  'percent',
#  'of',
#  'time',
#  'spent',
#  'is',
#  'preparing',
#  'data,',
#  '20',
#  'percent',
#  'of',
#  'time',
#  'is',
#  'spent',
#  'complaining',
#  'about',
#  'the',
#  'need',
#  'to',
#  'prepare',
#  'data.']

# %%
" ".join(hidden_words_prueba)
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
