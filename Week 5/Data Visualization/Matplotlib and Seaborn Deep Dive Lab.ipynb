# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do it both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)

fig2= plt.figure(figsize=(8,5))
plt.subplot(2, 1, 1) 
plt.plot(x, y, '--', color='b')

plt.subplot(2, 1, 2)
plt.plot(x, z, c='r', lw=5)

# %%
# your code here-2nd way (call `subplots` only once not using the `index` parameter)

fig, axes = plt.subplots(1,1)
plt.plot(x, y, '--', color='b')

plt.plot(x, z, c='r', lw=5)

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here

fig2= plt.figure(figsize=(8,5))
plt.subplot(2, 1, 1)
plt.plot(x, y, '--', color='b')

plt.subplot(2, 1, 2)
plt.plot(x, z, c='r', lw=5)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here

fig2= plt.figure(figsize=(14,6))
plt.subplot(1, 2, 1)
plt.plot(x, y, '--', color='b', label='x and y values')
plt.legend()
plt.xlabel('xlabel', fontsize=11)
plt.ylabel('ylabel', fontsize=11)

plt.subplot(1, 2, 2)
plt.plot(x, z, c='r', lw=5, label='x and z values')
plt.legend()
plt.xlabel('xlabel', fontsize=11)
plt.ylabel('ylabel', fontsize=11)
# Out:
# Text(0, 0.5, 'ylabel')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here

import math

y1 = x**2
y2 = math.e**x
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(121)
plt.plot(x, y1, '--', color='b')
plt.plot(x, y2, '--', color='r')
ax.set_xscale('linear')
ax.set_yscale('linear')


ax = fig.add_subplot(122)
plt.plot(x, y1, '--', color='b')
plt.plot(x, y2, '--', color='r')
ax.set_xscale('log')
ax.set_yscale('log')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here

vehicles = pd.read_csv('./vehicles.csv')

# %%
x = vehicles['Combined MPG']
y = vehicles['Highway MPG']

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here

plt.boxplot(vehicles['CO2 Emission Grams/Mile'])
plt.show()

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here

plt.hist(vehicles['Fuel Barrels/Year'])
plt.show()

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here

plt.bar(vehicles['Fuel Type'], vehicles['City MPG'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Challenge 2

# %% [markdown]
# In this lab you will partner with another student to conduct **[pair programming](https://en.wikipedia.org/wiki/Pair_programming)**. In the next 60 minutes there will be 2 coding sessions of 30 minutes each. In each session, one student will be the **driver** to write the code to solve the problem while the other student will be the **observer** to watch and review. There will be several iterations of your code because the observer will help the driver review the codes and make improvements until the 15 minute session ends. After the coding session ends, the driver and observer will switch roles.

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Preparation
#
# #### Import the `Fitbit2.csv` file and name your dataset `fitbit`

# %%
fitbit=pd.read_csv('Fitbit2.csv')

fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# ## Coding Session I - 30 minutes
#
# From the Fitbit data, we want to visually understand:
#
# 1. **How the average number of steps change by month. Use the appropriate visualization to show the mean steps by month?**
# 1. **Is Fitbit more active on weekend or workdays?**
#
# ##### All plots must be in the same jupyter notebook cell.
#
# Hints:
#
# - Use `Months_encoded` and `Week_or Weekend` columns
# - Use `matplolib.pyplot` object oriented API
# - Set your size figure to `12,4`
# - Explore `plt.sca`
# - Explore `plt.xticks`
# - Save your figures

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %%
monthly_steps = fitbit.groupby('Months_encoded')['Steps'].mean()

fig1 = plt.figure(figsize=(12, 4))
plt.bar(monthly_steps.index, monthly_steps.values, color='gray')
plt.xticks(monthly_steps.index, ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
plt.savefig('/Users/miguel/Desktop/monthly_steps.png')


weekly_steps = fitbit.groupby(['Work_or_Weekend'])['Steps'].mean()

fig2 = plt.figure(figsize= (6, 2))
plt.barh(weekly_steps.index, weekly_steps.values, height= 0.9, color= 'blue')
plt.yticks([0, 1], ['Weekend', 'Work'])
plt.show()
plt.savefig('work_or_weekend.png')

# %% [markdown]
# ## Coding Session II - 30 minutes
#
# **Write a loop to plot 3 scatter plots of the following features:**
#
# 1. **`Minutes Lightly Active`  vs `Steps`**
# 1. **`Minutes Very Active` vs `Steps`**
# 1. **`Minutes Sedentary` vs `Steps`**

# %%
fitbit_cols = fitbit[['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']]

for col in fitbit_cols:
    plt.figure()
    plt.title(col + 'vs Steps')
    plt.xlabel('Steps')
    plt.ylabel(col)
    plt.scatter(fitbit['Steps'], fitbit[col], color= np.random.rand(3,))

# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here

titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable

titanic.select_dtypes(include=['float64', 'int64'])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable

titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
plt.style.use('classic')
fig = plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulization to show the distribution of the column `Age`

# %%
plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
plt.subplot(2, 2, 1) 
plt.hist(titanic['Age'], bins=10)
plt.title('Age distribution')

plt.subplot(2, 2, 2)
plt.hist(titanic['Age'], bins=20)

plt.subplot(2, 2, 3)
plt.hist(titanic['Age'], bins=50)
plt.show()

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
## Yes it does, since using more bins means more accurate data in this case, where we can see
## that most people in the titanic were around 25 and 30 years old, but we can confidentley say
## that actually the majority people were actually 30 and 24 years old.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
sns.set()
sns.histplot(data=titanic, x="Age")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
titanic['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=titanic, x="Gender")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
## that the median age in the boat was relatively low (~30 yo)
## and that anyone above 60 was an outlier!

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
sns.countplot(data=titanic, x="Pclass")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
sns.boxplot(y="Age", data=titanic)
# Out:
# <AxesSubplot:ylabel='Age'>

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
## That the median age in the Titanic was around 30 years old
## and that anyone above 60 was an outlier.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to show below.

# %%
sns.violinplot(x="Age", data = titanic)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
## The box plot inside of the violin gives us the distribution of all the data points.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
plt.figure()
plt.title('Relationship between Age and Fare')
plt.xlabel('Fare')
plt.ylabel('Age')
plt.scatter(titanic['Fare'], titanic['Age'])
plt.show()

# %%
sns.jointplot('Fare', 'Age', data=titanic, kind='reg')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
sns.heatmap(titanic[['Pclass', 'Age', 'Fare', 'Survived']].corr(), vmin=-1, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
## Fare and PClass and parch are the most positively correlated. 
## Age and PClass and parch are the most negatively correlated.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
sns.boxplot(data=titanic, x="Pclass", y="Age")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
multigrafica = sns.FacetGrid(titanic, col='Gender', margin_titles=True)
multigrafica.map(plt.hist, 'Age')
