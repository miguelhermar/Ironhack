# %%
import mysql.connector
import pandas as pd

# %%
mydb = mysql.connector.connect(host="localhost", user="root", password="Ranasverdes3", database="publications")

print(mydb)

# %%
conn = pymysql.connect(host="localhost", user="root", password="Ranasverdes3", database="publications")

print(conn)

# %%
cursor = mydb.cursor()

cursor.execute("Show tables;")
 
myresult = cursor.fetchall()
 
for x in myresult:
    print(x)
# Out:
# ('authors',)
# ('discounts',)
# ('employee',)
# ('jobs',)
# ('pub_info',)
# ('publishers',)
# ('roysched',)
# ('sales',)
# ('stores',)
# ('titleauthor',)
# ('titles',)

# %%
publications_tables=pd.read_sql_query('SHOW TABLES FROM publications', mydb)
publications_tables
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    Tables_in_publications
# 0                 authors
# 1               discounts
# 2                employee
# 3                    jobs
# 4                pub_info
# 5              publishers
# 6                roysched
# 7                   sales
# 8                  stores
# 9             titleauthor
# 10                 titles

# %%
tables =publications_tables['Tables_in_publications']

# %%
# %load_ext sql

# %%
## export PATH=:/usr/local/mysql/bin

## mysql -u root -p

## ALTER USER 'root'@'localhost' \
## IDENTIFIED WITH mysql_native_password \
## BY '[Ranasverdes3]';

## conda install mysqlclient

# %%
# %sql mysql+mysqldb://root:Ranasverdes3@localhost/publications

# %%
# %%sql
#
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema='publications';
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 11 rows affected.
# [('authors',),
#  ('discounts',),
#  ('employee',),
#  ('jobs',),
#  ('pub_info',),
#  ('publishers',),
#  ('roysched',),
#  ('sales',),
#  ('stores',),
#  ('titleauthor',),
#  ('titles',)]

# %%
for table_name in tables:
    output=pd.read_sql_query('DESCRIBE {}'.format(table_name),mydb)
    print(table_name)
    print(output,'\n')
# Out:
# authors
#       Field            Type Null  Key Default Extra
# 0     au_id  b'varchar(11)'   NO  PRI    None
# 1  au_lname  b'varchar(40)'   NO         None
# 2  au_fname  b'varchar(20)'   NO         None
# 3     phone     b'char(12)'   NO         None
# 4   address  b'varchar(40)'  YES         None
# 5      city  b'varchar(20)'  YES         None
# 6     state      b'char(2)'  YES         None
# 7       zip      b'char(5)'  YES         None
# 8  contract      b'tinyint'   NO         None
#
# discounts
#           Field             Type Null  Key Default Extra
# 0  discounttype   b'varchar(40)'   NO         None
# 1       stor_id       b'char(4)'  YES  MUL    None
# 2        lowqty      b'smallint'  YES         None
# 3       highqty      b'smallint'  YES         None
# 4      discount  b'decimal(4,2)'   NO         None
#
# employee
#        Field            Type Null  Key Default Extra
# 0     emp_id      b'char(9)'   NO  PRI    None
# 1      fname  b'varchar(20)'   NO         None
# ...

# %%
# %%sql
#
# SELECT * FROM authors
# limit 3;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 3 rows affected.
# [('172-32-1176', 'White', 'Johnson', '408 496-7223', '10932 Bigge Rd.', 'Menlo Park', 'CA', '94025', 1),
#  ('213-46-8915', 'Green', 'Marjorie', '415 986-7020', '309 63rd St. #411', 'Oakland', 'CA', '94618', 1),
#  ('238-95-7766', 'Carson', 'Cheryl', '415 548-7723', '589 Darwin Ln.', 'Berkeley', 'CA', '94705', 1)]

# %%
# %%sql
#
# SELECT * FROM titles
# limit 3;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 3 rows affected.
# [('BU1032', "The Busy Executive's Database Guide", 'business', '1389', Decimal('19.9900'), Decimal('5000.0000'), 10, 4095, 'An overview of available database systems with emphasis on common business applications. Illustrated.', datetime.datetime(1991, 6, 12, 0, 0)),
#  ('BU1111', 'Cooking with Computers: Surreptitious Balance Sheets', 'business', '1389', Decimal('11.9500'), Decimal('5000.0000'), 10, 3876, 'Helpful hints on how to use your electronic resources to the best advantage.', datetime.datetime(1991, 6, 9, 0, 0)),
#  ('BU2075', 'You Can Combat Computer Stress!', 'business', '0736', Decimal('2.9900'), Decimal('10125.0000'), 24, 18722, 'The latest medical and psychological techniques for living with the electronic office. Easy-to-understand explanations.', datetime.datetime(1991, 6, 30, 0, 0))]

# %%
# %%sql
#
# SELECT * FROM titleauthor;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 25 rows affected.
# [('172-32-1176', 'PS3333', 1, 100),
#  ('213-46-8915', 'BU1032', 2, 40),
#  ('213-46-8915', 'BU2075', 1, 100),
#  ('238-95-7766', 'PC1035', 1, 100),
#  ('267-41-2394', 'BU1111', 2, 40),
#  ('267-41-2394', 'TC7777', 2, 30),
#  ('274-80-9391', 'BU7832', 1, 100),
#  ('409-56-7008', 'BU1032', 1, 60),
#  ('427-17-2319', 'PC8888', 1, 50),
#  ('472-27-2349', 'TC7777', 3, 30),
#  ('486-29-1786', 'PC9999', 1, 100),
#  ('486-29-1786', 'PS7777', 1, 100),
#  ('648-92-1872', 'TC4203', 1, 100),
#  ('672-71-3249', 'TC7777', 1, 40),
#  ('712-45-1867', 'MC2222', 1, 100),
#  ('722-51-5454', 'MC3021', 1, 75),
#  ('724-80-9391', 'BU1111', 1, 60),
#  ('724-80-9391', 'PS1372', 2, 25),
#  ('756-30-7391', 'PS1372', 1, 75),
#  ('807-91-6654', 'TC3218', 1, 100),
#  ('846-92-7186', 'PC8888', 2, 50),
#  ('899-46-2035', 'MC3021', 2, 25),
#  ('899-46-2035', 'PS2091', 2, 50),
#  ('998-72-3567', 'PS2091', 1, 50),
# ...

# %%
# %%sql
#
# SELECT * FROM publishers
# limit 3;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 3 rows affected.
# [('0736', 'New Moon Books', 'Boston', 'MA', 'USA'),
#  ('0877', 'Binnet & Hardley', 'Washington', 'DC', 'USA'),
#  ('1389', 'Algodata Infosystems', 'Berkeley', 'CA', 'USA')]

# %%
# %%sql
#
# SELECT * FROM sales
# limit 3;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 3 rows affected.
# [('6380', '6871', datetime.datetime(1994, 9, 14, 0, 0), 5, 'Net 60', 'BU1032'),
#  ('6380', '722a', datetime.datetime(1994, 9, 13, 0, 0), 3, 'Net 60', 'PS2091'),
#  ('7066', 'A2976', datetime.datetime(1993, 5, 24, 0, 0), 50, 'Net 30', 'PC8888')]

# %% [markdown]
# ### Challenge 1 - Who Have Published What At Where?

# %% [markdown]
# In this challenge you will write a MySQL SELECT query that joins various tables to figure out what titles each author has published at which publishers. Your output should have at least the following columns:
#
# AUTHOR ID - the ID of the author <br/>
# LAST NAME - author last name <br/>
# FIRST NAME - author first name <br/>
# TITLE - name of the published title <br/>
# PUBLISHER - name of the publisher where the title was published
#
# If your query is correct, the total rows in your output should be the same as the total number of records in Table titleauthor.

# %%
# %%sql
#
# SELECT authors.au_id, au_lname, au_fname, title, pub_name FROM authors
# JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# JOIN titles
# ON titleauthor.title_id = titles.title_id
# JOIN publishers
# ON titles.pub_id = publishers.pub_id;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 25 rows affected.
# [('213-46-8915', 'Green', 'Marjorie', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('409-56-7008', 'Bennet', 'Abraham', "The Busy Executive's Database Guide", 'Algodata Infosystems'),
#  ('267-41-2394', "O'Leary", 'Michael', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems'),
#  ('724-80-9391', 'MacFeather', 'Stearns', 'Cooking with Computers: Surreptitious Balance Sheets', 'Algodata Infosystems'),
#  ('213-46-8915', 'Green', 'Marjorie', 'You Can Combat Computer Stress!', 'New Moon Books'),
#  ('274-80-9391', 'Straight', 'Dean', 'Straight Talk About Computers', 'Algodata Infosystems'),
#  ('712-45-1867', 'del Castillo', 'Innes', 'Silicon Valley Gastronomic Treats', 'Binnet & Hardley'),
#  ('722-51-5454', 'DeFrance', 'Michel', 'The Gourmet Microwave', 'Binnet & Hardley'),
#  ('899-46-2035', 'Ringer', 'Anne', 'The Gourmet Microwave', 'Binnet & Hardley'),
# ...

# %% [markdown]
# ### Challenge 2 - Who Have Published How Many At Where?

# %% [markdown]
# Elevating from your solution in Challenge 1, query how many titles each author has published at each publisher.

# %% [markdown]
# To check if your output is correct, sum up the TITLE COUNT column. The sum number should be the same as the total number of records in Table titleauthor.
#
# Hint: In order to count the number of titles published by an author, you need to use MySQL COUNT. Also check out MySQL Group By because you will count the rows of different groups of data. Refer to the references and learn by yourself. These features will be formally discussed in the Temp Tables and Subqueries lesson.

# %%
# %%sql
#
# SELECT pub_name, au_lname, au_fname, COUNT(title) as number_of_titles FROM authors
# JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# JOIN titles
# ON titleauthor.title_id = titles.title_id
# JOIN publishers
# ON titles.pub_id = publishers.pub_id
# GROUP BY pub_name, au_lname, au_fname;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 24 rows affected.
# [('Algodata Infosystems', 'Green', 'Marjorie', 1),
#  ('Algodata Infosystems', 'Bennet', 'Abraham', 1),
#  ('Algodata Infosystems', "O'Leary", 'Michael', 1),
#  ('Algodata Infosystems', 'MacFeather', 'Stearns', 1),
#  ('New Moon Books', 'Green', 'Marjorie', 1),
#  ('Algodata Infosystems', 'Straight', 'Dean', 1),
#  ('Binnet & Hardley', 'del Castillo', 'Innes', 1),
#  ('Binnet & Hardley', 'DeFrance', 'Michel', 1),
#  ('Binnet & Hardley', 'Ringer', 'Anne', 1),
#  ('Algodata Infosystems', 'Carson', 'Cheryl', 1),
#  ('Algodata Infosystems', 'Dull', 'Ann', 1),
#  ('Algodata Infosystems', 'Hunter', 'Sheryl', 1),
#  ('Algodata Infosystems', 'Locksley', 'Charlene', 1),
#  ('Binnet & Hardley', 'MacFeather', 'Stearns', 1),
#  ('Binnet & Hardley', 'Karsen', 'Livia', 1),
#  ('New Moon Books', 'Ringer', 'Anne', 1),
#  ('New Moon Books', 'Ringer', 'Albert', 2),
#  ('New Moon Books', 'White', 'Johnson', 1),
# ...

# %% [markdown]
# ### Challenge 3 - Best Selling Authors

# %% [markdown]
# Who are the top 3 authors who have sold the highest number of titles? Write a query to find out.
#
# Requirements:
#
# Your output should have the following columns: <br/>
# AUTHOR ID - the ID of the author <br/>
# LAST NAME - author last name <br/>
# FIRST NAME - author first name <br/>
# TOTAL - total number of titles sold from this author <br/>
# Your output should be ordered based on TOTAL from high to low. <br/>
# Only output the top 3 best selling authors. <br/>
#
# Hint: In order to calculate the total of profits of an author, you need to use the MySQL SUM function. Refer to the reference and learn how to use it.

# %%
# %%sql
#
# SELECT authors.au_id, au_lname, au_fname, SUM(qty) as number_of_sold_titles FROM authors
# JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# JOIN sales
# ON titleauthor.title_id = sales.title_id
# GROUP BY authors.au_id, au_lname, au_fname
# ORDER BY number_of_sold_titles DESC
# limit 5;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 5 rows affected.
# [('899-46-2035', 'Ringer', 'Anne', Decimal('148')),
#  ('998-72-3567', 'Ringer', 'Albert', Decimal('133')),
#  ('213-46-8915', 'Green', 'Marjorie', Decimal('50')),
#  ('427-17-2319', 'Dull', 'Ann', Decimal('50')),
#  ('846-92-7186', 'Hunter', 'Sheryl', Decimal('50'))]

# %% [markdown]
# ### Challenge 4 - Best Selling Authors Ranking

# %% [markdown]
# Now modify your solution in Challenge 3 so that the output will display all 23 authors instead of the top 3. Note that the authors who have sold 0 titles should also appear in your output (ideally display 0 instead of NULL as the TOTAL). Also order your results based on TOTAL from high to low.

# %%
# %%sql
#
# SELECT authors.au_id, au_lname, au_fname, IFNULL(SUM(qty), 0) as number_of_sold_titles FROM authors
# RIGHT JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# RIGHT JOIN sales
# ON titleauthor.title_id = sales.title_id
# GROUP BY authors.au_id, au_lname, au_fname
#
# UNION
#
# SELECT authors.au_id, au_lname, au_fname, IFNULL(SUM(qty), 0) as number_of_sold_titles FROM authors
# LEFT JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# LEFT JOIN sales
# ON titleauthor.title_id = sales.title_id
# GROUP BY authors.au_id, au_lname, au_fname
#
# ORDER BY number_of_sold_titles DESC;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 23 rows affected.
# [('899-46-2035', 'Ringer', 'Anne', Decimal('148')),
#  ('998-72-3567', 'Ringer', 'Albert', Decimal('133')),
#  ('213-46-8915', 'Green', 'Marjorie', Decimal('50')),
#  ('427-17-2319', 'Dull', 'Ann', Decimal('50')),
#  ('846-92-7186', 'Hunter', 'Sheryl', Decimal('50')),
#  ('267-41-2394', "O'Leary", 'Michael', Decimal('45')),
#  ('724-80-9391', 'MacFeather', 'Stearns', Decimal('45')),
#  ('807-91-6654', 'Panteley', 'Sylvia', Decimal('40')),
#  ('722-51-5454', 'DeFrance', 'Michel', Decimal('40')),
#  ('238-95-7766', 'Carson', 'Cheryl', Decimal('30')),
#  ('486-29-1786', 'Locksley', 'Charlene', Decimal('25')),
#  ('648-92-1872', 'Blotchet-Halls', 'Reginald', Decimal('20')),
#  ('472-27-2349', 'Gringlesby', 'Burt', Decimal('20')),
#  ('672-71-3249', 'Yokomoto', 'Akiko', Decimal('20')),
#  ('756-30-7391', 'Karsen', 'Livia', Decimal('20')),
#  ('409-56-7008', 'Bennet', 'Abraham', Decimal('15')),
# ...

# %% [markdown]
# ### Bonus Challenge - Most Profiting Authors

# %% [markdown]
# Authors earn money from their book sales in two ways: advance and royalties. An advance is the money that the publisher pays the author before the book comes out. The royalties the author will receive is typically a percentage of the entire book sales. The total profit an author receives by publishing a book is the sum of the advance and the royalties.
#
# Given the information above, who are the 3 most profiting authors and how much royalties each of them have received? Write a query to find out.

# %% [markdown]
# Requirements:
#
# Your output should have the following columns: <br/>
# AUTHOR ID - the ID of the author <br/>
# LAST NAME - author last name <br/>
# FIRST NAME - author first name <br/>
# PROFIT - total profit the author has received combining the advance and royalties <br/>
# Your output should be ordered from higher PROFIT values to lower values. <br/>
# Only output the top 3 most profiting authors. <br/>
#
# Hints:
#
# If a title has multiple authors, how they split the royalties can be found in the royaltyper column of the titleauthor table. <br/>
# We assume the coauthors will split the advance in the same way as the royalties.

# %%
# %%sql
#
# SELECT authors.au_id, au_lname, au_fname, ((SUM(royaltyper*royalty)/100)+SUM(advance*royaltyper)/100) as profit FROM authors
# JOIN titleauthor
# ON titleauthor.au_id = authors.au_id
# JOIN titles
# ON titleauthor.title_id = titles.title_id
# GROUP BY authors.au_id, au_lname, au_fname
# ORDER BY profit DESC;
# Out:
#  * mysql+mysqldb://root:***@localhost/publications
# 19 rows affected.
# [('213-46-8915', 'Green', 'Marjorie', Decimal('12153.00000000')),
#  ('722-51-5454', 'DeFrance', 'Michel', Decimal('11268.00000000')),
#  ('998-72-3567', 'Ringer', 'Albert', Decimal('7153.50000000')),
#  ('238-95-7766', 'Carson', 'Cheryl', Decimal('7016.00000000')),
#  ('807-91-6654', 'Panteley', 'Sylvia', Decimal('7010.00000000')),
#  ('756-30-7391', 'Karsen', 'Livia', Decimal('5257.50000000')),
#  ('274-80-9391', 'Straight', 'Dean', Decimal('5010.00000000')),
#  ('899-46-2035', 'Ringer', 'Anne', Decimal('4899.50000000')),
#  ('724-80-9391', 'MacFeather', 'Stearns', Decimal('4758.50000000')),
#  ('267-41-2394', "O'Leary", 'Michael', Decimal('4407.00000000')),
#  ('648-92-1872', 'Blotchet-Halls', 'Reginald', Decimal('4014.00000000')),
#  ('486-29-1786', 'Locksley', 'Charlene', Decimal('4010.00000000')),
#  ('427-17-2319', 'Dull', 'Ann', Decimal('4005.00000000')),
# ...
